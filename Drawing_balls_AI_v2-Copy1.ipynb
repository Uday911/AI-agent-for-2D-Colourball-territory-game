# %%
import pygame
import random
import numpy as np
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
# Out:
# (5, 1)

# %%
pixell_array = 16777215

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch
from torch.autograd import variable

# %%
input_size = 2
output_size = 8

# %%
class Net(nn.Module):
    def __init__(self,input_channel,output_channel):
        self.input_channel = input_channel
        self.output_channel = output_channel
        super(Net,self).__init__()
        
        self.conv1 = nn.Conv2d(input_channel,32,3,padding=0)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.relu1 = nn.ReLU()
        
        self.conv2 = nn.Conv2d(32,32,3,padding=0)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.relu2 = nn.ReLU()
        
        self.fc1 = nn.Linear(1229312,output_channel)
        
    def forward(self,x):
        x = self.relu1(self.batch_norm1(self.conv1(x)))
        x = self.relu2(self.batch_norm2(self.conv2(x)))
        x = x.view(-1,1229312)
        x = self.fc1(x)
        return x

# %%
net1 = Net(input_size,output_size)
net2 = Net(input_size,output_size)
sm = nn.Softmax(dim=1)

# %%
def up(x,y):
    y-= 10
    return x,y
    
def down(x,y):
    y+= 10
    return x,y

def left(x,y):
    x -= 10
    return x,y

def right(x,y):
    x += 10
    return x,y

def upright(x,y):
    x += 10
    y -= 10
    return x,y

def upleft(x,y):
    x -= 10
    y -= 10
    return x,y

def downright(x,y):
    x += 10
    y += 10
    return x,y

def downleft(x,y):
    x -= 10
    y += 10
    return x,y

# %%
moves = (up,down,left,right,upright,upleft,downright,downleft)

# %%
def move_array(move):
    one = moves.index(move)
    array = [0]*8
    array[one] = 1
    return array

# %%
def move_indx(m):
    return moves.index(m)

# %%
def move_reverser(m):
    if m == up:
        return down
    if m == down:
        return up
    if m == left:
        return right
    if m == right:
        return left
    if m == upleft:
        return downright
    if m == downright:
        return upleft
    if m == upright:
        return downleft
    if m == downleft:
        return upright

# %%
objective = nn.CrossEntropyLoss()
optimizer1 = optim.Adam(params=net1.parameters(), lr=0.01)

# %%
#Winners = []
#episodes_batch = [[],[]]
#episodes_memory = [[],[]]
for z in range(100000):
    print("Episode No. ", z)
    red_moves = []
    black_moves = []
    states = []
    states_reversed = []
    area = []
    Won = ""
    fps = pygame.time.Clock()
    width = 200
    height = 200
    x = 180
    y = 25
    x_b = 25
    y_b = 180

    red = [255,0,0]
    white = [255,255,255]
    black = [0,0,0]
    win = pygame.display.set_mode((width,height))
    pygame.display.set_caption('First_world')
    win.fill(white)
    run = True
    while run:
        u = []
    #    x,y = random.choice(moves)(x,y)
    #    x_b,y_b = random.choice(moves)(x_b,y_b)
        if x > width-20:
            x=(width-20)
        if x < 20:
            x = (20)

        if y > height-20:
            y=(height-20)
        if y < 20:
            y = (20)

        if x_b > width-20:
            x_b=(width-20)
        if x_b < 20:
            x_b = (20)

        if y_b > height-20:
            y_b=(height-20)
        if y_b < 20:
            y_b = (20)



        pygame.draw.circle(win,red,(x,y),10)
        pygame.draw.circle(win,black,(x_b,y_b),10)
    #    pygame.draw.circle(win,red,(x+dx,y+dy),20)

        pygame.display.update()
    #    win.fill(white)
        fps.tick(60)

        for i in range(200):
            for j in range(200):
                u.append(win.get_at((i,j)))

        blacks = u.count((0, 0, 0, 255))
        reds = u.count((255, 0, 0, 255))

        area.append((blacks,reds))

        im_win = pygame.PixelArray(win)
        im_red = im_win.extract(pygame.Color(255, 0, 0, 255))
        im_red = np.array(im_red)/pixell_array
        im_black = im_win.extract(pygame.Color(0, 0, 0, 255))
        im_black = np.array(im_black)/pixell_array

        batch = torch.Tensor([im_red,im_black])
        batch= batch.view(-1,2,200,200)
        states.append(batch)
        move_probs1 = sm(net1(torch.FloatTensor(batch))).tolist()[0]

        probs1 = np.array(move_probs1)
        move1 = np.random.choice(moves,p=probs1/sum(probs1))
        red_moves.append(move1)
        x,y = move1(x,y)


        move_probs2 = sm(net2(torch.FloatTensor(batch))).tolist()[0]

        probs2 = np.array(move_probs2)
        move2 = np.random.choice(moves,p=probs2/sum(probs2))
        black_moves.append(move2)
        x_b,y_b = move2(x_b,y_b)


        if (area[-1][0]/sum(area[-1]) > 0.7) | (area[-1][1]/sum(area[-1]) > 0.7) :
            if (area[-1][0]/sum(area[-1]) > 0.7):
                print('Black ball won!!!')
                Won = 'Black'
                Winners.append(Won)
                run = False
            if (area[-1][1]/sum(area[-1]) > 0.7):
                print('Red ball won!!!')
                Won = 'Red'
                Winners.append(Won)
                run = False

    #    pygame.time.delay(20)
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
                
        if len(states) > 250:
            print("Tie")
            Won = "Tie"
            Winners.append(Won)
            run = False

    pygame.quit()
    if Won == 'Red':
        red_moves_array = list(map(move_indx,red_moves))
    #    black_moves_array = list(map(move_indx,black_moves))
        episodes_memory[0].extend(states)
        episodes_memory[1].extend(red_moves_array)
        if len(episodes_memory[0]) > 20000:
            del episodes_memory[0][:len(states)]
            del episodes_memory[1][:len(red_moves_array)]
    if len(episodes_memory[0]) > 5000:
        buff = random.sample(list(zip(episodes_memory[0],episodes_memory[1])),100)
        for i,j in buff:
            episodes_batch[0].append(i)
            episodes_batch[1].append(j)
        print("Training Red Ball!!!")
        train1 = []
        for i in episodes_batch[0]:
            move_probs = sm(net1(torch.FloatTensor(i.view(-1,2,200,200)))).tolist()[0]
            train1.append(move_probs)
        batch_size = len(episodes_batch[1])
        loss_v = objective(variable(torch.FloatTensor(train1), requires_grad=True).view(-1,8,batch_size),torch.LongTensor([episodes_batch[1]]))
        print("Loss is ",loss_v)
        optimizer1.zero_grad()
        loss_v.backward()
        optimizer1.step()
       

    if Won == 'Black':
        black_moves_reversed = list(map(move_reverser,black_moves))
        black_moves_array_reversed = list(map(move_indx,black_moves_reversed))
        for i in states:
            im_black_reversed = np.rot90(np.rot90(i.view(2,200,200)[0]))
            im_red_reversed = np.rot90(np.rot90(i.view(2,200,200)[1]))
            batch_reversed = torch.Tensor([im_red_reversed,im_black_reversed])
            batch_reversed.view(-1,2,200,200)
            states_reversed.append(batch_reversed)
            
        episodes_memory[0].extend(states_reversed)
        episodes_memory[1].extend(black_moves_array_reversed)
        if len(episodes_memory[0]) > 20000:
            del episodes_memory[0][:len(states_reversed)]
            del episodes_memory[1][:len(black_moves_array_reversed)]
# Out:
# Episode No.  0
# Tie
# Training Red Ball!!!
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py:167: UserWarning: torch.autograd.variable(...) is deprecated, use torch.tensor(...) instead
#   warnings.warn("torch.autograd.variable(...) is deprecated, use torch.tensor(...) instead")
# Loss is  tensor(2.0801, grad_fn=<NllLoss2DBackward>)
# Episode No.  1
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0804, grad_fn=<NllLoss2DBackward>)
# Episode No.  2
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0802, grad_fn=<NllLoss2DBackward>)
# Episode No.  3
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0792, grad_fn=<NllLoss2DBackward>)
# Episode No.  4
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  5
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0804, grad_fn=<NllLoss2DBackward>)
# Episode No.  6
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  7
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0800, grad_fn=<NllLoss2DBackward>)
# Episode No.  8
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0792, grad_fn=<NllLoss2DBackward>)
# Episode No.  9
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  10
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0793, grad_fn=<NllLoss2DBackward>)
# Episode No.  11
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0799, grad_fn=<NllLoss2DBackward>)
# Episode No.  12
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  13
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0801, grad_fn=<NllLoss2DBackward>)
# Episode No.  14
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0801, grad_fn=<NllLoss2DBackward>)
# Episode No.  15
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0804, grad_fn=<NllLoss2DBackward>)
# Episode No.  16
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  17
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0806, grad_fn=<NllLoss2DBackward>)
# Episode No.  18
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  19
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0803, grad_fn=<NllLoss2DBackward>)
# Episode No.  20
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  21
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0801, grad_fn=<NllLoss2DBackward>)
# Episode No.  22
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  23
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0800, grad_fn=<NllLoss2DBackward>)
# Episode No.  24
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  25
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0799, grad_fn=<NllLoss2DBackward>)
# Episode No.  26
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  27
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0799, grad_fn=<NllLoss2DBackward>)
# Episode No.  28
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  29
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  30
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  31
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  32
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  33
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  34
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  35
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0802, grad_fn=<NllLoss2DBackward>)
# Episode No.  36
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0799, grad_fn=<NllLoss2DBackward>)
# Episode No.  37
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  38
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  39
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  40
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  41
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  42
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  43
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  44
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  45
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  46
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  47
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  48
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  49
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  50
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  51
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  52
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  53
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  54
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  55
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  56
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  57
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  58
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0793, grad_fn=<NllLoss2DBackward>)
# Episode No.  59
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  60
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  61
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  62
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  63
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  64
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  65
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  66
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  67
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  68
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  69
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  70
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0799, grad_fn=<NllLoss2DBackward>)
# Episode No.  71
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  72
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  73
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0798, grad_fn=<NllLoss2DBackward>)
# Episode No.  74
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  75
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  76
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0793, grad_fn=<NllLoss2DBackward>)
# Episode No.  77
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  78
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0795, grad_fn=<NllLoss2DBackward>)
# Episode No.  79
# Black ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0796, grad_fn=<NllLoss2DBackward>)
# Episode No.  80
# Tie
# Training Red Ball!!!
# Loss is  tensor(2.0797, grad_fn=<NllLoss2DBackward>)
# Episode No.  81
# Red ball won!!!
# Training Red Ball!!!
# Loss is  tensor(2.0794, grad_fn=<NllLoss2DBackward>)
# Episode No.  82
# Tie
# Training Red Ball!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-3de4733dd690> in <module>()
#     133         train1 = []
#     134         for i in episodes_batch[0]:
# --> 135             move_probs = sm(net1(torch.FloatTensor(i.view(-1,2,200,200)))).tolist()[0]
#     136             train1.append(move_probs)
#     137         batch_size = len(episodes_batch[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-6-41ed952b1c59> in forward(self, x)
#      16
#      17     def forward(self,x):
# ---> 18         x = self.relu1(self.batch_norm1(self.conv1(x)))
#      19         x = self.relu2(self.batch_norm2(self.conv2(x)))
#      20         x = x.view(-1,1229312)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\batchnorm.py in forward(self, input)
#      64             input, self.running_mean, self.running_var, self.weight, self.bias,
#      65             self.training or not self.track_running_stats,
# ---> 66             exponential_average_factor, self.eps)
#      67
#      68     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1252     return torch.batch_norm(
#    1253         input, weight, bias, running_mean, running_var,
# -> 1254         training, momentum, eps, torch.backends.cudnn.enabled
#    1255     )
#    1256
#
# KeyboardInterrupt:

# %%
#pygame.quit()

# %%
def win_stats():
    length = len(Winners)
    reds = Winners.count('Red')
    blacks = Winners.count('Black')
    ties = Winners.count('Tie')
    print("Total Episodes palyed: {0}, Reds Won: {1}, Blacks Won: {2}, Ties: {3}".format(length,reds,blacks,ties))

print(win_stats())
# Out:
# Total Episodes palyed: 262, Reds Won: 56, Blacks Won: 62, Ties: 144
# None

# %%
len(episodes_memory[0])
# Out:
# 7780

# %%
#loss = (torch.sum(torch.mul(torch.log_softmax(net1(batch),dim = 1).view(-1,8,11), variable(discounted_rewards)).mul(-1), -1))
